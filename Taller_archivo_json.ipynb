# %% [markdown]
# ##1

# %%
{
  "nombreCompleto": "Juan Pérez",
  "edad": 28,
  "ciudadResidencia": "Madrid"
}
# Out:
# {'nombreCompleto': 'Juan Pérez', 'edad': 28, 'ciudadResidencia': 'Madrid'}

# %%
public class Persona {
    private String nombreCompleto;
    private int edad;
    private String ciudadResidencia;

    public Persona(String nombreCompleto, int edad, String ciudadResidencia) {
        this.nombreCompleto = nombreCompleto;
        this.edad = edad;
        this.ciudadResidencia = ciudadResidencia;
    }
}

# %% [markdown]
# ##2

# %%
{
  "id": 101,
  "nombreProducto": "Auriculares Bluetooth",
  "precio": 49.99
}
# Out:
# {'id': 101, 'nombreProducto': 'Auriculares Bluetooth', 'precio': 49.99}

# %%
public class Producto {
    private int id;
    private String nombreProducto;
    private double precio;

    public Producto(int id, String nombreProducto, double precio) {
        this.id = id;
        this.nombreProducto = nombreProducto;
        this.precio = precio;
    }
}

# %% [markdown]
# ##3

# %%
{
  "marca": "Toyota",
  "modelo": "Corolla",
  "anioFabricacion": 2020
}
# Out:
# {'marca': 'Toyota', 'modelo': 'Corolla', 'anioFabricacion': 2020}

# %%
public class Vehiculo {
    private String marca;
    private String modelo;
    private int anioFabricacion;

    public Vehiculo(String marca, String modelo, int anioFabricacion) {
        this.marca = marca;
        this.modelo = modelo;
        this.anioFabricacion = anioFabricacion;
    }
}

# %% [markdown]
# ##4

# %%
[
  {
    "id": 1,
    "nombre": "Ana Torres",
    "calificacionFinal": 9.2
  },
  {
    "id": 2,
    "nombre": "Luis Gómez",
    "calificacionFinal": 8.5
  },
  {
    "id": 3,
    "nombre": "María López",
    "calificacionFinal": 9.8
  }
]
# Out:
# [{'id': 1, 'nombre': 'Ana Torres', 'calificacionFinal': 9.2},
#  {'id': 2, 'nombre': 'Luis Gómez', 'calificacionFinal': 8.5},
#  {'id': 3, 'nombre': 'María López', 'calificacionFinal': 9.8}]

# %%
public class Estudiante {
    private int id;
    private String nombre;
    private double calificacionFinal;

    public Estudiante(int id, String nombre, double calificacionFinal) {
        this.id = id;
        this.nombre = nombre;
        this.calificacionFinal = calificacionFinal;
    }
}

# %% [markdown]
# ##5

# %%
{
  "nombre": "TechSoluciones",
  "anioFundacion": 2010,
  "direccion": {
    "calle": "Av. Reforma 123",
    "ciudad": "Ciudad de México"
  }
}
# Out:
# {'nombre': 'TechSoluciones',
#  'anioFundacion': 2010,
#  'direccion': {'calle': 'Av. Reforma 123', 'ciudad': 'Ciudad de México'}}

# %%
public class Empresa {
    private String nombre;
    private int anioFundacion;
    private Direccion direccion;

    public Empresa(String nombre, int anioFundacion, Direccion direccion) {
        this.nombre = nombre;
        this.anioFundacion = anioFundacion;
        this.direccion = direccion;
    }
}

class Direccion {
    private String calle;
    private String ciudad;

    public Direccion(String calle, String ciudad) {
        this.calle = calle;
        this.ciudad = ciudad;
    }
}

# %% [markdown]
# ##6

# %%
{
  "titulo": "Cien Años de Soledad",
  "numeroPaginas": 417
}
# Out:
# {'titulo': 'Cien Años de Soledad', 'numeroPaginas': 417}

# %%
public class Libro {
    private String titulo;
    private int numeroPaginas;

    public Libro(String titulo, int numeroPaginas) {
        this.titulo = titulo;
        this.numeroPaginas = numeroPaginas;
    }
}

# %% [markdown]
# ##7

# %%
{
  "nombre": "Pedro",
  "edad": 30
}
# Out:
# {'nombre': 'Pedro', 'edad': 30}

# %%
// JSON corregido ya válido:
String jsonValido = "{\"nombre\": \"Pedro\", \"edad\": 30}";

# %% [markdown]
# ##8

# %%
[
  {
    "id": 1,
    "nombre": "Laptop",
    "precio": 899.99
  },
  {
    "id": 2,
    "nombre": "Smartphone",
    "precio": 699.49
  },
  {
    "id": 3,
    "nombre": "Tablet",
    "precio": 299.99
  }
]
# Out:
# [{'id': 1, 'nombre': 'Laptop', 'precio': 899.99},
#  {'id': 2, 'nombre': 'Smartphone', 'precio': 699.49},
#  {'id': 3, 'nombre': 'Tablet', 'precio': 299.99}]

# %%
import java.util.List;

public class ProductoTecnologico {
    private int id;
    private String nombre;
    private double precio;

    public ProductoTecnologico(int id, String nombre, double precio) {
        this.id = id;
        this.nombre = nombre;
        this.precio = precio;
    }
}

// Lista de productos:
List<ProductoTecnologico> productos = List.of(
    new ProductoTecnologico(1, "Laptop", 899.99),
    new ProductoTecnologico(2, "Smartphone", 699.49),
    new ProductoTecnologico(3, "Tablet", 299.99)
);

# %% [markdown]
# ##9

# %%
{
  "temperatura": 22.5,
  "humedad": 65,
  "ciudad": "Barcelona"
}
# Out:
# {'temperatura': 22.5, 'humedad': 65, 'ciudad': 'Barcelona'}

# %%
public class DatosClimaticos {
    private double temperatura;
    private int humedad;
    private String ciudad;

    public DatosClimaticos(double temperatura, int humedad, String ciudad) {
        this.temperatura = temperatura;
        this.humedad = humedad;
        this.ciudad = ciudad;
    }
}

# %% [markdown]
# ##10

# %%
{
  "id": 7,
  "nombreUsuario": "usuario123",
  "correoElectronico": "usuario123@example.com"
}
# Out:
# {'id': 7,
#  'nombreUsuario': 'usuario123',
#  'correoElectronico': 'usuario123@example.com'}

# %%
public class Usuario {
    private int id;
    private String nombreUsuario;
    private String correoElectronico;

    public Usuario(int id, String nombreUsuario, String correoElectronico) {
        this.id = id;
        this.nombreUsuario = nombreUsuario;
        this.correoElectronico = correoElectronico;
    }
}
